# %% [markdown]
# EDA, comenzamos importando las librerias con las que podemos llegar a trabajar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
font = {'size' : 14}
import matplotlib
matplotlib.rc('font', **font)
import seaborn as sns

# %%
df_internet_baf = pd.read_csv("Internet_BAF (1).csv")
df_internet_baf["Trimestre"] = df_internet_baf["Trimestre"].astype("category")
df_internet_baf["Año"] = df_internet_baf["Año"].astype("category")
df_internet_baf["Periodo"] = df_internet_baf["Periodo"].astype("category")
df_internet_baf["Banda ancha fija"] = df_internet_baf["Banda ancha fija"].str.replace(".", "").astype("int64")
df_internet_baf["Total"] = df_internet_baf["Total"].str.replace(".", "").astype("int64")
df_internet_baf["Dial up"] = df_internet_baf["Dial up"].apply(lambda x: int(x * 1000) if pd.notnull(x) else x)

### Agregar columnas al dataset

# Calcular el porcentaje de cada categoria en relación del total.
df_internet_baf["Dial_porcent"] = round((df_internet_baf["Dial up"] / df_internet_baf["Total"]) * 100, 2)
df_internet_baf["Banda_porcent"] = round((df_internet_baf["Banda ancha fija"] / df_internet_baf["Total"]) * 100, 2)

df_internet_baf = df_internet_baf.sort_index(ascending=False)

# Calcular el porcentaje de crecimiento Anual y Trimestral.
df_internet_baf['Porcentaje_Crecimiento_Trimestral'] = round(df_internet_baf['Total'].pct_change() * 100,2)

df_internet_baf['Porcentaje_Crecimiento_Anual'] = round((df_internet_baf['Total'] - df_internet_baf['Total'].shift(4)) / df_internet_baf['Total'].shift(4) * 100, 2)

# Guardar el archivo
df_internet_baf.to_csv("Transformados/internet_xcategoria_general.csv",index=True)
df_internet_baf
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1005378284.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_internet_baf["Banda ancha fija"] = df_internet_baf["Banda ancha fija"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1005378284.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_internet_baf["Total"] = df_internet_baf["Total"].str.replace(".", "").astype("int64")
#      Año Trimestre  Banda ancha fija  Dial up     Total        Periodo  \
# 34  2014         1           6362108    36290   6398398   Ene-Mar 2014
# 33  2014         2           6428329    36139   6464468   Abr-Jun 2014
# 32  2014         3           6559264    36007   6595271  Jul-Sept 2014
# 31  2014         4           6559172    39324   6598496   Oct-Dic 2014
# 30  2015         1           6699714    38018   6737732   Ene-Mar 2015
# 29  2015         2           6783279    32909   6816188   Abr-Jun 2015
# 28  2015         3           6902267    32801   6935068  Jul-Sept 2015
# 27  2015         4           6952289    32542   6984831   Oct-Dic 2015
# 26  2016         1           6874704    32652   6907356   Ene-Mar 2016
# 25  2016         2           7097604    32475   7130079   Abr-Jun 2016
# 24  2016         3           7178340    28610   7206950  Jul-Sept 2016
# 23  2016         4           7223128    28545   7251673   Oct-Dic 2016
# 22  2017         1           7277314    28540   7305854   Ene-Mar 2017
# 21  2017         2           7401134    28530   7429664   Abr-Jun 2017
# 20  2017         3           7696594    28349   7724943  Jul-Sept 2017
# 19  2017         4           7842778    27444   7870222   Oct-Dic 2017
# 18  2018         1           8009981    27072   8037053   Ene-Mar 2018
# 17  2018         2           8083533    26911   8110444   Abr-Jun 2018
# 16  2018         3           8320223    26812   8347035  Jul-Sept 2018
# 15  2018         4           8451841    21814   8473655   Oct-Dic 2018
# 14  2019         1           8626323    21812   8648135   Ene-Mar 2019
# 13  2019         2           8938427    21754   8960181   Abr-Jun 2019
# 12  2019         3           9142891    21793   9164684  Jul-Sept 2019
# 11  2019         4           8783053    10128   8793181   Oct-Dic 2019
# 10  2020         1           8802435     9991   8812426   Ene-Mar 2020
# 9   2020         2           9021040    10016   9031056   Abr-Jun 2020
# 8   2020         3           9346183    10016   9356199  Jul-Sept 2020
# 7   2020         4           9561546    10016   9571562   Oct-Dic 2020
# 6   2021         1           9637956    10016   9647972   Ene-Mar 2021
# 5   2021         2           9852702    10382   9863084   Abr-Jun 2021
# 4   2021         3          10075184    10357  10085541  Jul-Sept 2021
# 3   2021         4          10476933    12861  10489794   Oct-Dic 2021
# 2   2022         1          10611390    12619  10624009   Ene-Mar 2022
# 1   2022         2          10946248    12436  10958684   Abr-Jun 2022
# 0   2022         3          11078691    12437  11091128  Jul-Sept 2022
#
#     Dial_porcent  Banda_porcent  Porcentaje_Crecimiento_Trimestral  \
# 34          0.57          99.43                                NaN
# 33          0.56          99.44                               1.03
# 32          0.55          99.45                               2.02
# 31          0.60          99.40                               0.05
# 30          0.56          99.44                               2.11
# 29          0.48          99.52                               1.16
# 28          0.47          99.53                               1.74
# 27          0.47          99.53                               0.72
# 26          0.47          99.53                              -1.11
# 25          0.46          99.54                               3.22
# 24          0.40          99.60                               1.08
# 23          0.39          99.61                               0.62
# 22          0.39          99.61                               0.75
# 21          0.38          99.62                               1.69
# 20          0.37          99.63                               3.97
# 19          0.35          99.65                               1.88
# 18          0.34          99.66                               2.12
# 17          0.33          99.67                               0.91
# 16          0.32          99.68                               2.92
# 15          0.26          99.74                               1.52
# 14          0.25          99.75                               2.06
# 13          0.24          99.76                               3.61
# 12          0.24          99.76                               2.28
# 11          0.12          99.88                              -4.05
# 10          0.11          99.89                               0.22
# 9           0.11          99.89                               2.48
# 8           0.11          99.89                               3.60
# 7           0.10          99.90                               2.30
# 6           0.10          99.90                               0.80
# 5           0.11          99.89                               2.23
# 4           0.10          99.90                               2.26
# 3           0.12          99.88                               4.01
# 2           0.12          99.88                               1.28
# 1           0.11          99.89                               3.15
# 0           0.11          99.89                               1.21
#
#     Porcentaje_Crecimiento_Anual
# 34                           NaN
# 33                           NaN
# 32                           NaN
# 31                           NaN
# 30                          5.30
# 29                          5.44
# 28                          5.15
# 27                          5.85
# 26                          2.52
# 25                          4.61
# 24                          3.92
# 23                          3.82
# 22                          5.77
# 21                          4.20
# 20                          7.19
# 19                          8.53
# 18                         10.01
# 17                          9.16
# 16                          8.05
# 15                          7.67
# 14                          7.60
# 13                         10.48
# 12                          9.80
# 11                          3.77
# 10                          1.90
# 9                           0.79
# 8                           2.09
# 7                           8.85
# 6                           9.48
# 5                           9.21
# 4                           7.80
# 3                           9.59
# 2                          10.12
# 1                          11.11
# 0                           9.97

# %% [markdown]
# Verificamos datos especificamente el desvío estantardar y el promedio del porcentaje de cremiento anual y trimestral, tambien el porcentaje de categoria(datos tomados del dataset expuesto previamente y analisis del cuadro .describe() del mismo puesto a continuación).

# %%
## Tomamos valores de referencia para un posible KPI

#Porcentaje_crecimiento_Trimestral mean = 1.642353 , std = 1.536959	
#Porcentaje_crecimiento_anual mean = 6.766129 , std = 2.929388

## El promedio de crecimiento trimestral desde el 2020 en adelante es de 2,1.

## Durante los ultimos 2 años el min de promedio de crecimiento fue de 7,8


df_internet_baf.describe()
# Out:
#        Banda ancha fija       Dial up         Total  Dial_porcent  \
# count      3.500000e+01     35.000000  3.500000e+01     35.000000
# mean       8.274417e+06  23383.371429  8.297800e+06      0.307714
# std        1.408774e+06  10087.397193  1.399611e+06      0.170744
# min        6.362108e+06   9991.000000  6.398398e+06      0.100000
# 25%        7.024946e+06  12436.500000  7.057455e+06      0.115000
# 50%        8.083533e+06  26911.000000  8.110444e+06      0.330000
# 75%        9.244537e+06  32508.500000  9.260442e+06      0.465000
# max        1.107869e+07  39324.000000  1.109113e+07      0.600000
#
#        Banda_porcent  Porcentaje_Crecimiento_Trimestral  \
# count      35.000000                          34.000000
# mean       99.692286                           1.642353
# std         0.170744                           1.536959
# min        99.400000                          -4.050000
# 25%        99.535000                           0.940000
# 50%        99.670000                           1.810000
# 75%        99.885000                           2.295000
# max        99.900000                           4.010000
#
#        Porcentaje_Crecimiento_Anual
# count                     31.000000
# mean                       6.766129
# std                        2.929388
# min                        0.790000
# 25%                        4.405000
# 50%                        7.600000
# 75%                        9.345000
# max                       11.110000

# %%
# Ordenar el DataFrame por el índice en sentido ascendente
df_internet_baf_sorted = df_internet_baf.sort_index(ascending=True)

# Crear el gráfico de barras utilizando seaborn
ax = sns.barplot(data=df_internet_baf_sorted, x=df_internet_baf_sorted.index, y="Total")

# Obtener las etiquetas de las marcas del eje x según el orden del índice
xtick_labels = df_internet_baf_sorted["Periodo"].tolist()

# Asignar las etiquetas de las marcas del eje x
ax.set_xticklabels(xtick_labels, rotation=90, ha='center')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# El grafico muestra que hay un crecimiento Trimestral sostenido, interrumpido en 2 ocasiones, el más pronunciado fue de -4.05 en en el perido Oct-Dic 2019. Esto es coincidente con un momento donde en la Republica Argentina ocurrió una devaluación abrupta del dolar producida por la incertidumbre politica de una elección que preveía un cambio de signo politico en el gobierno.
#
# No se verifica caída de crecimiento interanual
#
# Desde finales del 2020 se verifica un crecimiento prnunciado hasta la actualidad

# %%
## El grafico muestra que hay un crecimiento sostenido, interrumpido en 2 ocasiones por una caida en el total, el más pronunciado generado en un periodo donde ocurrió una devaluación abrupta del dolar producida por la incertidumbre politica de una eleccion que preveía un cambio de signo politico en el gobierno.
## Desde finales del 2020 se verifica un crecimiento prnunciado hasta la actualidad

# %%
# Ordenar el DataFrame por el índice en sentido ascendente
df_internet_baf_sorted = df_internet_baf

# Crear el gráfico de líneas utilizando seaborn
sns.lineplot(data=df_internet_baf_sorted, x=df_internet_baf_sorted["Año"], y="Banda ancha fija", marker="o")
sns.lineplot(data=df_internet_baf_sorted, x=df_internet_baf_sorted["Año"], y="Total", marker="o")

# Establecer etiquetas y título del gráfico
plt.xlabel("Periodo")
plt.ylabel("Valores")
plt.title("Gráfico de Líneas de Banda ancha y Total por Periodo")

# Mostrar leyenda
plt.legend(["Banda ancha fija", "Total"])

# Rotar las etiquetas del eje x
plt.xticks(rotation=90, ha='center')

# Ajustar el diseño del gráfico
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
#  Se verifica por el grafico que la linea que representa el "total" de accesos por categoria y la cantidad de banda ancha es casi la misma que el total. El promedio de del porcentaje del total de banda ancha es de 99.7 del total con una variación estandar de 0,17
#
#  Concentrarnos en trabajar con conexiones de categoria Dial UP no sería provechoso dado su porcentaje y su nivel casi nulo de idoneidad para las necesidades comunicacioneles de la sociedad a día de hoy.

# %%
## Analizamos el dataset de categorias por provincias

df_internet_baf_2 = pd.read_csv("Internet_BAF (2).csv")
df_internet_baf_2["Año"] = df_internet_baf_2["Año"].astype("category")
df_internet_baf_2["Trimestre"] = df_internet_baf_2["Trimestre"].astype("category")
df_internet_baf_2["Provincia"] = df_internet_baf_2["Provincia"].astype("category")
df_internet_baf_2["Banda ancha fija"] = df_internet_baf_2["Banda ancha fija"].str.replace(".", "").astype("int64")
df_internet_baf_2["Dial up"] = df_internet_baf_2["Dial up"].str.replace("[^0-9]", "", regex=True)
df_internet_baf_2["Dial up"] = df_internet_baf_2["Dial up"].fillna(0)

df_internet_baf_2["Total"] = df_internet_baf_2["Total"].str.replace(".", "").astype("int64")
df_internet_baf_2["Dial up"] = df_internet_baf_2["Dial up"].astype("int64")

## generamos una columna que mida el porcentaje del total para los 24 distritos/provincias
## gracias esto podemos determinar que el distrito mas grande tiene una relacion de 3 a 1 en cuanto a tasa del total en comparación con el segundo
## Verificamos que el 73% del total está en distrubido en el mercado 


Total_trimestre = df_internet_baf_2.groupby(['Año', 'Trimestre'])['Total'].sum()
df_internet_baf_2['Proporción'] = df_internet_baf_2['Total'] / df_internet_baf_2.apply(lambda row: Total_trimestre[(row['Año'], row['Trimestre'])], axis=1)
df_internet_baf_2['Proporción'] = df_internet_baf_2['Proporción'].round(4)
df_internet_baf_2.head(24)

df_internet_baf_2 = df_internet_baf_2.sort_values(['Año', 'Trimestre', 'Provincia'])
df_internet_baf_2['Crecimiento Trimestral'] = df_internet_baf_2.groupby('Provincia')['Total'].pct_change() * 100
df_internet_baf_2['Crecimiento Anual'] = df_internet_baf_2.groupby('Provincia')['Total'].pct_change(periods=4) * 100
df_internet_baf_2 = df_internet_baf_2.sort_index(ascending=True)
#filtro = (df_internet_baf_2["Año"] == 2022) & (df_internet_baf_2["Trimestre"] == 3)
filtro = (df_internet_baf_2["Provincia"] == "Buenos Aires")
df_internet_baf_2_filtrado = df_internet_baf_2[filtro]
#.sort_values("Total",ascending=False)
df_internet_baf_2_filtrado
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\663161066.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_internet_baf_2["Banda ancha fija"] = df_internet_baf_2["Banda ancha fija"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\663161066.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_internet_baf_2["Total"] = df_internet_baf_2["Total"].str.replace(".", "").astype("int64")
#       Año Trimestre     Provincia  Banda ancha fija  Dial up    Total  \
# 0    2022         3  Buenos Aires           4715469     6199  4721668
# 24   2022         2  Buenos Aires           4660984     6199  4667183
# 48   2022         1  Buenos Aires           4549131     6293  4555424
# 72   2021         4  Buenos Aires           4502772     6385  4509157
# 96   2021         3  Buenos Aires           4246425     5184  4251609
# 120  2021         2  Buenos Aires           4127167     5184  4132351
# 144  2021         1  Buenos Aires           4054936     5066  4060002
# 168  2020         4  Buenos Aires           4028195     5066  4033261
# 192  2020         3  Buenos Aires           3932211     5066  3937277
# 216  2020         2  Buenos Aires           3772480     5066  3777546
# 240  2020         1  Buenos Aires           3702985     5066  3708051
# 264  2019         4  Buenos Aires           3681120     5134  3686254
# 288  2019         3  Buenos Aires           3950114    10119  3960233
# 312  2019         2  Buenos Aires           3845594    10104  3855698
# 336  2019         1  Buenos Aires           3736563    10104  3746667
# 360  2018         4  Buenos Aires           3626502    10104  3636606
# 384  2018         3  Buenos Aires           3599714    10563  3610277
# 408  2018         2  Buenos Aires           3490134    10565  3500699
# 432  2018         1  Buenos Aires           3464882    10564  3475446
# 456  2017         4  Buenos Aires           3171206    10690  3181896
# 480  2017         3  Buenos Aires           3046758    11202  3057960
# 504  2017         2  Buenos Aires           3067430    11201  3078631
# 528  2017         1  Buenos Aires           3178174    11202  3189376
# 552  2016         4  Buenos Aires           3131499    11202  3142701
# 576  2016         3  Buenos Aires           3075387    11205  3086592
# 600  2016         2  Buenos Aires           3032776    12515  3045291
# 624  2016         1  Buenos Aires           2929903    12612  2942515
# 648  2015         4  Buenos Aires           2946743    12642  2959385
# 672  2015         3  Buenos Aires           2916070    12695  2928765
# 696  2015         2  Buenos Aires           2871079    12711  2883790
# 720  2015         1  Buenos Aires           2847076    14766  2861842
# 744  2014         4  Buenos Aires           2801178    15229  2816407
# 768  2014         3  Buenos Aires           2835537    14028  2849565
# 792  2014         2  Buenos Aires           2750430    14116  2764546
# 816  2014         1  Buenos Aires           2725732    14144  2739876
#
#      Proporción  Crecimiento Trimestral  Crecimiento Anual
# 0        0.4257                1.167407          11.056026
# 24       0.4259                2.453317          12.942560
# 48       0.4288                1.026068          12.202506
# 72       0.4299                6.057660          11.799286
# 96       0.4216                2.885960           7.983487
# 120      0.4190                1.781994           9.392473
# 144      0.4208                0.663012           9.491536
# 168      0.4214                2.437827           9.413540
# 192      0.4208                4.228433          -0.579663
# 216      0.4183                1.874165          -2.026922
# 240      0.4208                0.591305          -1.030676
# 264      0.4192               -6.918255           1.365229
# 288      0.4321                2.711182           9.693328
# 312      0.4303                2.910080          10.140803
# 336      0.4332                3.026476           7.803919
# 360      0.4292                0.729279          14.290536
# 384      0.4325                3.130175          18.061616
# 408      0.4316                0.726612          13.709600
# 432      0.4324                9.225632           8.969466
# 456      0.4043                4.052898           1.247176
# 480      0.3959               -0.671435          -0.927625
# 504      0.4144               -3.472309           1.094805
# 528      0.4366                1.485187           8.389456
# 552      0.4334                1.817830           6.194395
# 576      0.4283                1.356225           5.388858
# 600      0.4271                3.492794           5.600304
# 624      0.4260               -0.570051           2.818919
# 648      0.4237                1.045492           5.076610
# 672      0.4223                1.559580           2.779372
# 696      0.4231                0.766919           4.313330
# 720      0.4247                1.613226           4.451515
# 744      0.4268               -1.163616                NaN
# 768      0.4321                3.075333                NaN
# 792      0.4277                0.900406                NaN
# 816      0.4282                     NaN                NaN

# %% [markdown]
# Verificamos que el 74% del total está en distrubido en los 4 primeros distritos("Buenos Aires, Capital Federal, Córdoba, Santa Fe") que se encuentran ubicados en la zona centro del país
#
# el otro 26% está repartido en 20 distritos

# %%
df_internet_baf_2.describe()
# Out:
#        Banda ancha fija       Dial up         Total  Proporción  \
# count      8.400000e+02    840.000000  8.400000e+02  840.000000
# mean       3.447674e+05    974.307143  3.457417e+05    0.041665
# std        7.400503e+05   2418.317775  7.419436e+05    0.088521
# min        1.219300e+04      0.000000  1.255700e+04    0.001800
# 25%        5.192225e+04      9.000000  5.202975e+04    0.006075
# 50%        1.029360e+05    148.000000  1.034895e+05    0.012500
# 75%        1.778685e+05    619.000000  1.779148e+05    0.022700
# max        4.715469e+06  15229.000000  4.721668e+06    0.436600
#
#        Porcentaje de Crecimiento
# count                 816.000000
# mean                    3.097915
# std                    14.557903
# min                   -31.378056
# 25%                     0.201249
# 50%                     1.175120
# 75%                     2.864362
# max                   246.660145

# %% [markdown]
# A partir del .describe() que está a continuacion podemos ver que el valor de crecimiento del distrito más importante que representa un 43% del país tiene coincidencia con los valoresa nivel país de "Promedio de crecimiento" tanto trimestral como anual.
#
# ##### Porcentaje de Crecimiento
# PAIS TRIMESTRAL mean = 1.642353 , std = 1.536959 \
# PAIS ANUAL mean = 6.766129 , std = 2.929388
#
# BUENOS AIRES TRIMESTRAL mean = 1.646965 , std = 2.631343 \
# BUENOS AIRES ANUAL mean = 6.809863 , std = 5.123398

# %%
filtro = (df_internet_baf_2["Provincia"] == "Buenos Aires")
df_internet_baf_2_filtrado = df_internet_baf_2[filtro]
df_internet_baf_2_filtrado.describe()
# Out:
#        Banda ancha fija       Dial up         Total  Proporción  \
# count      3.500000e+01     35.000000  3.500000e+01   35.000000
# mean       3.514696e+06   9719.742857  3.524416e+06    0.424803
# std        5.996429e+05   3380.681147  5.967349e+05    0.008119
# min        2.725732e+06   5066.000000  2.739876e+06    0.395900
# 25%        2.989760e+06   6199.000000  3.002338e+06    0.421100
# 50%        3.490134e+06  10564.000000  3.500699e+06    0.426000
# 75%        3.941162e+06  12563.500000  3.948755e+06    0.430100
# max        4.715469e+06  15229.000000  4.721668e+06    0.436600
#
#        Crecimiento Trimestral  Crecimiento Anual
# count               34.000000          31.000000
# mean                 1.646965           6.809863
# std                  2.631343           5.123398
# min                 -6.918255          -2.026922
# 25%                  0.738689           2.799145
# 50%                  1.586403           7.803919
# 75%                  2.904050           9.917066
# max                  9.225632          18.061616

# %%
filtro = (df_internet_baf_2["Provincia"] == "Santa Fe")
df_internet_baf_2_filtrado = df_internet_baf_2[filtro]
df_internet_baf_2_filtrado.describe()
# Out:
#        Banda ancha fija    Dial up          Total  Proporción  \
# count         35.000000   35.00000      35.000000   35.000000
# mean      684115.171429  349.40000  684464.571429    0.082231
# std       128533.243617  231.57367  128329.166160    0.003159
# min       506000.000000  110.00000  506612.000000    0.076400
# 25%       561257.500000  150.50000  561752.000000    0.079750
# 50%       684243.000000  256.00000  684552.000000    0.082600
# 75%       790328.000000  606.00000  790465.000000    0.085200
# max       887700.000000  938.00000  887810.000000    0.087500
#
#        Crecimiento Trimestral  Crecimiento Anual
# count               34.000000          31.000000
# mean                 1.700143           7.155600
# std                  2.868949           5.344917
# min                 -1.722714           0.028486
# 25%                  0.694506           4.625778
# 50%                  1.129662           5.887148
# 75%                  1.884448           7.594693
# max                 16.757510          20.811467

# %%
filtro = (df_internet_baf_2["Provincia"] == "Capital Federal")
df_internet_baf_2_filtrado = df_internet_baf_2[filtro]
df_internet_baf_2_filtrado.describe()
# Out:
#        Banda ancha fija       Dial up         Total  Proporción  \
# count      3.500000e+01     35.000000  3.500000e+01   35.000000
# mean       1.396189e+06   5856.542857  1.402046e+06    0.172966
# std        7.725690e+04   3743.923637  7.620441e+04    0.026042
# min        1.289204e+06   1390.000000  1.299918e+06    0.133400
# 25%        1.356563e+06   2145.000000  1.357963e+06    0.148550
# 50%        1.384824e+06   6688.000000  1.389020e+06    0.168800
# 75%        1.410866e+06   9788.500000  1.412762e+06    0.197650
# max        1.592175e+06  11994.000000  1.600191e+06    0.215400
#
#        Crecimiento Trimestral  Crecimiento Anual
# count               34.000000          31.000000
# mean                 0.592935           1.730395
# std                  4.018511           6.623983
# min                -13.635261         -14.436089
# 25%                 -0.110677          -0.918683
# 50%                  0.595878           2.523467
# 75%                  1.074892           3.543247
# max                 14.377297          14.743250

# %%
filtro = (df_internet_baf_2["Provincia"] == "Córdoba")
df_internet_baf_2_filtrado = df_internet_baf_2[filtro]
df_internet_baf_2_filtrado.describe()
# Out:
#        Banda ancha fija     Dial up         Total  Proporción  \
# count      3.500000e+01   35.000000  3.500000e+01   35.000000
# mean       7.503283e+05  131.314286  7.504596e+05    0.090146
# std        1.442544e+05   76.246802  1.441945e+05    0.002727
# min        5.667050e+05   55.000000  5.669100e+05    0.085400
# 25%        6.302575e+05   68.000000  6.304920e+05    0.088400
# 50%        7.138250e+05  105.000000  7.139260e+05    0.089500
# 75%        8.519150e+05  202.500000  8.519700e+05    0.092650
# max        1.038600e+06  319.000000  1.038668e+06    0.094500
#
#        Crecimiento Trimestral  Crecimiento Anual
# count               34.000000          31.000000
# mean                 1.809497           7.518031
# std                  1.631207           3.129158
# min                 -2.578625           1.674733
# 25%                  0.909372           4.677966
# 50%                  1.717529           8.411727
# 75%                  2.486499           9.952861
# max                  5.931227          12.302074

# %%
# Ordenar el DataFrame por el índice en sentido ascendente
df_internet_baf_2_sorted = df_internet_baf_2.sort_index(ascending=True)

# Crear el gráfico de líneas utilizando seaborn

sns.lineplot(data=df_internet_baf_2_sorted, x=df_internet_baf_2_sorted["Año"], y="Total", hue="Provincia", marker="o")

# Establecer etiquetas y título del gráfico
plt.xlabel("Periodo")
plt.ylabel("Valores")
plt.title("Gráfico de Líneas de Banda ancha y Total por Periodo")

# Rotar las etiquetas del eje x
plt.xticks(rotation=90, ha='center')

# Mostrar leyenda
plt.legend(title="Provincia")

# Ajustar el tamaño del gráfico en el eje Y
plt.ylim(bottom=0)  # Establecer el límite inferior en 0

# Ajustar el diseño del gráfico
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\2014781160.py:23: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
nea_provincias = ["Chaco", "Corrientes", "Formosa", "Misiones"]
noa_provincias = ["Santiago del Estero", "Tucumán", "Catamarca", "Jujuy", "Salta"]
centro_provincias = ["Santa Fe", "Córdoba", "Entre Ríos"]
cuyo_provincias = ["La Rioja", "Mendoza", "San Juan", "San Luis"]
bsas_provincias = ["Buenos Aires", "Capital Federal"]
patagonia_provincias = ["La Pampa", "Neuquén", "Rio Negro", "Chubut", "Santa Cruz", "Tierra del Fuego"]

# %%
# Lista de provincias que deseas mostrar en el gráfico
nea_provincias = ["Chaco", "Corrientes", "Formosa", "Misiones"]

# Filtrar el DataFrame por las provincias seleccionadas
df_provincias_seleccionadas = df_internet_baf_2_sorted[df_internet_baf_2_sorted["Provincia"].isin(nea_provincias)]

# Definir un diccionario de mapeo entre provincias y colores
mapeo_colores = {"Chaco": "blue", "Corrientes": "red", "Formosa": "green", "Misiones": "orange"}

# Obtener los colores correspondientes a las provincias seleccionadas
colores = [mapeo_colores[provincia] for provincia in df_provincias_seleccionadas["Provincia"]]

# Crear el gráfico de líneas utilizando seaborn con las provincias seleccionadas
grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=colores)

# Filtrar las etiquetas de la leyenda para mostrar solo las provincias seleccionadas
handles, labels = grafico.get_legend_handles_labels()
nueva_etiquetas = [label for label in labels if label in nea_provincias]
grafico.legend(handles, nueva_etiquetas, title="Provincias")

# Resto del código...

# Mostrar el gráfico
plt.show()

df_provincias_seleccionadas
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\2018546952.py:14: UserWarning: The palette list has more values (140) than needed (24), which may not be intended.
#   grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=colores)
#       Año Trimestre   Provincia  Banda ancha fija  Dial up   Total
# 3    2022         3       Chaco            144141        5  144146
# 6    2022         3  Corrientes            144842        4  144846
# 8    2022         3     Formosa             68537        1   68538
# 13   2022         3    Misiones            182157        0  182157
# 27   2022         2       Chaco            143559        5  143564
# ..    ...       ...         ...               ...      ...     ...
# 805  2014         2    Misiones             74689        0   74689
# 819  2014         1       Chaco             62520       36   62556
# 822  2014         1  Corrientes             62203       33   62236
# 824  2014         1     Formosa             25335       87   25422
# 829  2014         1    Misiones             73950        0   73950
#
# [140 rows x 6 columns]

# %%
# Lista de provincias que deseas mostrar en el gráfico
noa_provincias = ["Santiago Del Estero", "Tucumán", "Catamarca", "Jujuy", "Salta"]

# Filtrar el DataFrame por las provincias seleccionadas
df_provincias_seleccionadas = df_internet_baf_2_sorted[df_internet_baf_2_sorted["Provincia"].isin(noa_provincias)]

# Definir una paleta de colores predefinida
paleta_colores = sns.color_palette("husl", n_colors=len(noa_provincias))

# Crear el gráfico de líneas utilizando seaborn con las provincias seleccionadas y la paleta de colores
grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# Filtrar las etiquetas de la leyenda para mostrar solo las provincias seleccionadas
handles, labels = grafico.get_legend_handles_labels()
nueva_etiquetas = [label for label in labels if label in noa_provincias]
grafico.legend(handles, nueva_etiquetas, title="Provincias")

# Resto del código...

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\3965317904.py:11: UserWarning:
# The palette list has fewer values (5) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# %%
# Lista de provincias que deseas mostrar en el gráfico
centro_provincias = ["Santa Fe", "Córdoba", "Entre Ríos"]

# Filtrar el DataFrame por las provincias seleccionadas
df_provincias_seleccionadas = df_internet_baf_2_sorted[df_internet_baf_2_sorted["Provincia"].isin(centro_provincias)]

# Definir una paleta de colores predefinida
paleta_colores = sns.color_palette("husl", n_colors=len(centro_provincias))

# Crear el gráfico de líneas utilizando seaborn con las provincias seleccionadas y la paleta de colores
grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# Filtrar las etiquetas de la leyenda para mostrar solo las provincias seleccionadas
handles, labels = grafico.get_legend_handles_labels()
nueva_etiquetas = [label for label in labels if label in centro_provincias]
grafico.legend(handles, nueva_etiquetas, title="Provincias")

# Resto del código...

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\2135464124.py:11: UserWarning:
# The palette list has fewer values (3) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# %%
# Lista de provincias que deseas mostrar en el gráfico
cuyo_provincias = ["La Rioja", "Mendoza", "San Juan", "San Luis"]
# Filtrar el DataFrame por las provincias seleccionadas
df_provincias_seleccionadas = df_internet_baf_2_sorted[df_internet_baf_2_sorted["Provincia"].isin(cuyo_provincias)]

# Definir una paleta de colores predefinida
paleta_colores = sns.color_palette("husl", n_colors=len(cuyo_provincias))

# Crear el gráfico de líneas utilizando seaborn con las provincias seleccionadas y la paleta de colores
grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# Filtrar las etiquetas de la leyenda para mostrar solo las provincias seleccionadas
handles, labels = grafico.get_legend_handles_labels()
nueva_etiquetas = [label for label in labels if label in cuyo_provincias]
grafico.legend(handles, nueva_etiquetas, title="Provincias")

# Resto del código...

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\3047413918.py:10: UserWarning:
# The palette list has fewer values (4) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# %%
# Lista de provincias que deseas mostrar en el gráfico
bsas_provincias = ["Buenos Aires", "Capital Federal"]
# Filtrar el DataFrame por las provincias seleccionadas
df_provincias_seleccionadas = df_internet_baf_2_sorted[df_internet_baf_2_sorted["Provincia"].isin(bsas_provincias)]

# Definir una paleta de colores predefinida
paleta_colores = sns.color_palette("husl", n_colors=len(bsas_provincias))

# Crear el gráfico de líneas utilizando seaborn con las provincias seleccionadas y la paleta de colores
grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# Filtrar las etiquetas de la leyenda para mostrar solo las provincias seleccionadas
handles, labels = grafico.get_legend_handles_labels()
nueva_etiquetas = [label for label in labels if label in bsas_provincias]
grafico.legend(handles, nueva_etiquetas, title="Provincias")

# Resto del código...

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1516843661.py:10: UserWarning:
# The palette list has fewer values (2) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# %%
# Lista de provincias que deseas mostrar en el gráfico
patagonia_provincias = ["La Pampa", "Neuquén", "Río Negro", "Chubut", "Santa Cruz", "Tierra Del Fuego"]
# Filtrar el DataFrame por las provincias seleccionadas
df_provincias_seleccionadas = df_internet_baf_2_sorted[df_internet_baf_2_sorted["Provincia"].isin(patagonia_provincias)]

# Definir una paleta de colores predefinida
paleta_colores = sns.color_palette("husl", n_colors=len(patagonia_provincias))

# Crear el gráfico de líneas utilizando seaborn con las provincias seleccionadas y la paleta de colores
grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# Filtrar las etiquetas de la leyenda para mostrar solo las provincias seleccionadas
handles, labels = grafico.get_legend_handles_labels()
nueva_etiquetas = [label for label in labels if label in patagonia_provincias]
grafico.legend(handles, nueva_etiquetas, title="Provincias")

# Resto del código...

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1777843779.py:10: UserWarning:
# The palette list has fewer values (6) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   grafico = sns.lineplot(data=df_provincias_seleccionadas, x="Año", y="Total", hue="Provincia", marker="o", palette=paleta_colores)

# %%
df_conectividad = pd.read_csv("ConectividadalserviciodeInternet_2776151689387082246.csv")

df_conectividad["Provincia"] = df_conectividad["Provincia"].astype("category")
df_conectividad["Partido"] = df_conectividad["Partido"].astype("category")
df_conectividad["Localidad"] = df_conectividad["Localidad"].astype("category")

df_conectividad.replace("--", "NO", inplace=True)
df_conectividad['ADSL'] = df_conectividad['ADSL'].astype("category")
df_conectividad['CABLEMODEM'] = df_conectividad['CABLEMODEM'].astype("category")
df_conectividad['DIALUP'] = df_conectividad['DIALUP'].astype("category")
df_conectividad['FIBRAOPTICA'] = df_conectividad['FIBRAOPTICA'].astype("category")
df_conectividad['SATELITAL'] = df_conectividad['SATELITAL'].astype("category")
df_conectividad['WIRELESS'] = df_conectividad['WIRELESS'].astype("category")
df_conectividad['TELEFONIAFIJA'] = df_conectividad['TELEFONIAFIJA'].astype("category")
df_conectividad['3G'] = df_conectividad['3G'].astype("category")
df_conectividad['4G'] = df_conectividad['4G'].astype("category")


df_conectividad.info()
df_conectividad.to_csv("Transformados\Conectividad_por_tipo_cat.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4312 entries, 0 to 4311
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      4312 non-null   category
#  1   Partido        4312 non-null   category
#  2   Localidad      4312 non-null   category
#  3   Poblacion      4312 non-null   int64
#  4   ADSL           4312 non-null   category
#  5   CABLEMODEM     4312 non-null   category
#  6   DIALUP         4312 non-null   category
#  7   FIBRAOPTICA    4312 non-null   category
#  8   SATELITAL      4312 non-null   category
#  9   WIRELESS       4312 non-null   category
#  10  TELEFONIAFIJA  4312 non-null   category
#  11  3G             4312 non-null   category
#  12  4G             4312 non-null   category
#  13  link           4300 non-null   float64
#  14  Latitud        4312 non-null   object
#  15  Longitud       4312 non-null   object
# dtypes: category(12), float64(1), int64(1), object(2)
# memory usage: 374.9+ KB

# %%
df_list_loc = pd.read_csv("Listadodelocalidadesconconectividadainternet_2750221689387075329.csv")
df_list_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4312 entries, 0 to 4311
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      4312 non-null   object
#  1   Partido        4312 non-null   object
#  2   Localidad      4312 non-null   object
#  3   ADSL           4312 non-null   object
#  4   CABLEMODEM     4312 non-null   object
#  5   DIALUP         4312 non-null   object
#  6   FIBRAOPTICA    4312 non-null   object
#  7   4G             4312 non-null   object
#  8   3G             4312 non-null   object
#  9   TELEFONIAFIJA  4312 non-null   object
#  10  WIRELESS       4312 non-null   object
#  11  SATELITAL      4312 non-null   object
# dtypes: object(12)
# memory usage: 404.4+ KB

# %%
columnas_compartidas = df_conectividad.columns.intersection(df_list_loc.columns)

# Verificar si los DataFrames tienen la misma información en las columnas compartidas
igual_informacion = df_conectividad[columnas_compartidas].equals(df_list_loc[columnas_compartidas])

if igual_informacion:
    print("Los DataFrames contienen la misma información en las columnas compartidas")
else:
    print("Los DataFrames no contienen la misma información en las columnas compartidas")
# Out:
# Los DataFrames no contienen la misma información en las columnas compartidas

# %%
df_acceso = pd.read_csv("AccesosaInternetfijoporvelocidaddebajadaylocalidad_2776171689387061180.csv")
df_acceso
# Out:
#          Provincia      Partido                           Localidad  \
# 0     BUENOS AIRES   25 de Mayo                          25 de Mayo
# 1     BUENOS AIRES   25 de Mayo                     Agustín Mosconi
# 2     BUENOS AIRES   25 de Mayo                           Del Valle
# 3     BUENOS AIRES   25 de Mayo                           Ernestina
# 4     BUENOS AIRES   25 de Mayo                   Gobernador Ugarte
# ...            ...          ...                                 ...
# 3093       TUCUMAN   Tafí Viejo  Villa Mariano Moreno - El Colmenar
# 3094       TUCUMAN      Trancas                San Pedro de Colalao
# 3095       TUCUMAN      Trancas                   Villa  de Trancas
# 3096       TUCUMAN  Yerba Buena                       Villa Carmela
# 3097       TUCUMAN  Yerba Buena            Yerba Buena - Marcos Paz
#
#      Link Indec Otros  0,256 mbps  0,375 mbps 0,5 mbps  0,512 mbps  \
# 0       6854100   NaN         NaN         NaN        2         NaN
# 1       6854010   NaN         NaN         NaN      NaN         NaN
# 2       6854020   NaN         NaN         NaN        1         NaN
# 3       6854030   NaN         NaN         NaN      NaN         NaN
# 4       6854040   NaN         NaN         NaN      NaN         NaN
# ...         ...   ...         ...         ...      ...         ...
# 3093   90105100   NaN         NaN         NaN      NaN         NaN
# 3094   90112020   NaN         NaN         NaN      NaN         NaN
# 3095   90112030   NaN         NaN         NaN      NaN         NaN
# 3096   90119020   NaN         NaN         NaN      NaN         NaN
# 3097   90119030   176         NaN         NaN      NaN         NaN
#
#       0,625 mbps  ... 75 mbps 78 mbps  80 mbps 82 mbps 83 mbps  85 mbps  \
# 0            NaN  ...     NaN     NaN      9.0     NaN     NaN      NaN
# 1            NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 2            NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 3            NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 4            NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# ...          ...  ...     ...     ...      ...     ...     ...      ...
# 3093         NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 3094         NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 3095         NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 3096         NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
# 3097         NaN  ...     NaN     NaN      NaN     NaN     NaN      NaN
#
#       90 mbps 92 mbps  95 mbps 100 mbps
# 0         NaN     NaN      NaN      NaN
# 1         NaN     NaN      NaN      NaN
# 2         NaN     NaN      NaN      NaN
# 3         NaN     NaN      NaN      NaN
# 4         NaN     NaN      NaN      NaN
# ...       ...     ...      ...      ...
# 3093      NaN     NaN      NaN      304
# 3094      NaN     NaN      NaN      NaN
# 3095      NaN     NaN      NaN      NaN
# 3096      NaN     NaN      NaN      NaN
# 3097      NaN     NaN      NaN    6,556
#
# [3098 rows x 83 columns]

# %%
df_acceso_per_tec = pd.read_csv("Internet_Accesos-por-tecnologia (2).csv")
df_acceso_per_tec["Año"] = df_acceso_per_tec["Año"].astype("category")
df_acceso_per_tec["Trimestre"] = df_acceso_per_tec["Trimestre"].astype("category")
df_acceso_per_tec["Periodo"] = df_acceso_per_tec["Periodo"].astype("category")

df_acceso_per_tec["ADSL"] = df_acceso_per_tec["ADSL"].str.replace(".", "").astype("int64")
df_acceso_per_tec["Cablemodem"] = df_acceso_per_tec["Cablemodem"].str.replace(".", "").astype("int64")
df_acceso_per_tec["Fibra óptica"] = df_acceso_per_tec["Fibra óptica"].str.replace(".", "").astype("int64")
df_acceso_per_tec["Wireless"] = df_acceso_per_tec["Wireless"].apply(lambda x: int(x * 1000))
df_acceso_per_tec["Otros"] = df_acceso_per_tec["Otros"].apply(lambda x: int(x * 1000))
df_acceso_per_tec["Total"] = df_acceso_per_tec["Total"].str.replace(".", "").astype("int64")
df_acceso_per_tec.to_csv(r"Transformados\acceso_xtec_xperiodo.csv")
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1873527085.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_tec["ADSL"] = df_acceso_per_tec["ADSL"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1873527085.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_tec["Cablemodem"] = df_acceso_per_tec["Cablemodem"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1873527085.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_tec["Fibra óptica"] = df_acceso_per_tec["Fibra óptica"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\1873527085.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_tec["Total"] = df_acceso_per_tec["Total"].str.replace(".", "").astype("int64")

# %%
df_acceso_per_vel = pd.read_csv("Internet_Accesos-por-velocidad (2).csv")
df_acceso_per_vel["Año"] = df_acceso_per_vel["Año"].astype("category")
df_acceso_per_vel["Trimestre"] = df_acceso_per_vel["Trimestre"].astype("category")
df_acceso_per_vel["Provincia"] = df_acceso_per_vel["Provincia"].astype("category")
df_acceso_per_vel["HASTA 512 kbps"] = df_acceso_per_vel["HASTA 512 kbps"].apply(lambda x: int(x * 1000))
df_acceso_per_vel["+ 512 Kbps - 1 Mbps"] = df_acceso_per_vel["+ 512 Kbps - 1 Mbps"].apply(lambda x: int(x * 1000))
df_acceso_per_vel["+ 1 Mbps - 6 Mbps"] = df_acceso_per_vel["+ 1 Mbps - 6 Mbps"].str.replace(".", "").astype("int64")
df_acceso_per_vel["+ 6 Mbps - 10 Mbps"] = df_acceso_per_vel["+ 6 Mbps - 10 Mbps"].apply(lambda x: int(x * 1000))
df_acceso_per_vel["+ 10 Mbps - 20 Mbps"] = df_acceso_per_vel["+ 10 Mbps - 20 Mbps"].apply(lambda x: int(x * 1000))
df_acceso_per_vel["+ 20 Mbps - 30 Mbps"] = df_acceso_per_vel["+ 20 Mbps - 30 Mbps"].apply(lambda x: int(x * 1000))
#df_acceso_per_vel["+ 512 Kbps - 1 Mbps"] = df_acceso_per_vel["+ 512 Kbps - 1 Mbps"].apply(lambda x: int(x * 1000))
df_acceso_per_vel["OTROS"] = df_acceso_per_vel["OTROS"].fillna(0)
df_acceso_per_vel["OTROS"] = df_acceso_per_vel["OTROS"].apply(lambda x: int(x * 1000 if x > 0 else 0))
df_acceso_per_vel["+ 30 Mbps"] = df_acceso_per_vel["+ 30 Mbps"].str.replace(".", "").astype("int64")
df_acceso_per_vel["Total"] = df_acceso_per_vel["Total"].str.replace(".", "").astype("int64")
df_acceso_per_vel["Total"]

df_acceso_per_vel.to_csv(r"Transformados\acceso_xvel_xperiodo_xprov.csv")
df_acceso_per_vel
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\668199826.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_vel["+ 1 Mbps - 6 Mbps"] = df_acceso_per_vel["+ 1 Mbps - 6 Mbps"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\668199826.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_vel["+ 30 Mbps"] = df_acceso_per_vel["+ 30 Mbps"].str.replace(".", "").astype("int64")
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16948\668199826.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_acceso_per_vel["Total"] = df_acceso_per_vel["Total"].str.replace(".", "").astype("int64")
#       Año Trimestre            Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0    2022         3         Buenos Aires           29985                27709
# 1    2022         3      Capital Federal          517000                 5742
# 2    2022         3            Catamarca           71000               384000
# 3    2022         3                Chaco          461000               987000
# 4    2022         3               Chubut          109000                 1444
# ..    ...       ...                  ...             ...                  ...
# 835  2014         1           Santa Cruz          161000                 1625
# 836  2014         1             Santa Fe            8456               124468
# 837  2014         1  Santiago Del Estero            1234                10531
# 838  2014         1     Tierra Del Fuego           12000               607000
# 839  2014         1              Tucumán            6000                34672
#
#      + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0               290315              297915               267044
# 1                34371               67829                51946
# 2                 3107                5389                 5099
# 3                16782               18938                 8048
# 4                45707               30940                34682
# ..                 ...                 ...                  ...
# 835              24972                1000                 1000
# 836             345225               20328                 6845
# 837              22817                2422               109000
# 838              30902                6000                    0
# 839              83210               11779               362000
#
#      + 20 Mbps - 30 Mbps  + 30 Mbps   OTROS    Total
# 0                 124190    3618689   65821  4721668
# 1                  28692    1253105  105477  1547679
# 2                   3737      50298    2208    70293
# 3                  15828      79390    3711   144146
# 4                  15309      17563   20024   165778
# ..                   ...        ...     ...      ...
# 835                    0          0       0    26760
# 836                23000        668       0   506013
# 837                    0          0       0    37113
# 838                    0          0       0    31527
# 839                 3000          0       0   130032
#
# [840 rows x 12 columns]

# %%
df_internet_penetracion_2 = pd.read_csv("Internet_Penetracion (2).csv")
'''
---  ------                        --------------  ----- 
 0   Año                           35 non-null     int64 
 1   Trimestre                     35 non-null     int64 
 2   Accesos por cada 100 hogares  35 non-null     object
 3   Accesos por cada 100 hab      35 non-null     object
 4   Periodo                       35 non-null     object
'''
df_internet_penetracion_2["Año"] = df_internet_penetracion_2["Año"].astype("category")
df_internet_penetracion_2["Trimestre"] = df_internet_penetracion_2["Trimestre"].astype("category")
df_internet_penetracion_2["Periodo"] = df_internet_penetracion_2["Periodo"].astype("category")

df_internet_penetracion_2["Accesos por cada 100 hogares"] = df_internet_penetracion_2["Accesos por cada 100 hogares"].str.replace(",", ".").astype("float64")
df_internet_penetracion_2["Accesos por cada 100 hab"] = df_internet_penetracion_2["Accesos por cada 100 hab"].str.replace(",", ".").astype("float64")
df_internet_penetracion_2.to_csv(r"Transformados\acceso_xhogares_general.csv")
df_internet_penetracion_2
# Out:
#      Año Trimestre  Accesos por cada 100 hogares  Accesos por cada 100 hab  \
# 0   2022         3                         76.64                     23.95
# 1   2022         2                         75.97                     23.72
# 2   2022         1                         73.88                     23.05
# 3   2021         4                         73.18                     22.81
# 4   2021         3                         70.58                     21.98
# 5   2021         2                         69.24                     21.55
# 6   2021         1                         67.95                     21.13
# 7   2020         4                         67.62                     21.01
# 8   2020         3                         66.31                     20.59
# 9   2020         2                         64.21                     19.92
# 10  2020         1                         62.86                     19.48
# 11  2019         4                         62.92                     19.49
# 12  2019         3                         65.79                     20.36
# 13  2019         2                         64.53                     19.96
# 14  2019         1                         62.48                     19.31
# 15  2018         4                         61.42                     18.97
# 16  2018         3                         60.69                     18.73
# 17  2018         2                         59.16                     18.24
# 18  2018         1                         58.82                     18.12
# 19  2017         4                         57.78                     17.79
# 20  2017         3                         56.90                     17.51
# 21  2017         2                         54.90                     16.88
# 22  2017         1                         54.16                     16.64
# 23  2016         4                         53.94                     16.56
# 24  2016         3                         53.73                     16.50
# 25  2016         2                         53.34                     16.37
# 26  2016         1                         51.85                     15.90
# 27  2015         4                         52.63                     16.12
# 28  2015         3                         52.46                     16.05
# 29  2015         2                         51.76                     15.82
# 30  2015         1                         51.36                     15.68
# 31  2014         4                         50.50                     15.39
# 32  2014         3                         50.67                     15.43
# 33  2014         2                         49.86                     15.16
# 34  2014         1                         49.55                     15.05
#
#           Periodo
# 0   Jul-Sept 2022
# 1    Abr-Jun 2022
# 2    Ene-Mar 2022
# 3    Oct-Dic 2021
# 4   Jul-Sept 2021
# 5    Abr-Jun 2021
# 6    Ene-Mar 2021
# 7    Oct-Dic 2020
# 8   Jul-Sept 2020
# 9    Abr-Jun 2020
# 10   Ene-Mar 2020
# 11   Oct-Dic 2019
# 12  Jul-Sept 2019
# 13   Abr-Jun 2019
# 14   Ene-Mar 2019
# 15   Oct-Dic 2018
# 16  Jul-Sept 2018
# 17   Abr-Jun 2018
# 18   Ene-Mar 2018
# 19   Oct-Dic 2017
# 20  Jul-Sept 2017
# 21   Abr-Jun 2017
# 22   Ene-Mar 2017
# 23   Oct-Dic 2016
# 24  Jul-Sept 2016
# 25   Abr-Jun 2016
# 26   Ene-Mar 2016
# 27   Oct-Dic 2015
# 28  Jul-Sept 2015
# 29   Abr-Jun 2015
# 30   Ene-Mar 2015
# 31   Oct-Dic 2014
# 32  Jul-Sept 2014
# 33   Abr-Jun 2014
# 34   Ene-Mar 2014

# %%
df_internet_penetracion_1 = pd.read_csv("Internet_Penetracion (1).csv")
df_internet_penetracion_1["Año"] = df_internet_penetracion_1["Año"].astype("category")
df_internet_penetracion_1["Trimestre"] = df_internet_penetracion_1["Trimestre"].astype("category")
df_internet_penetracion_1["Provincia"] = df_internet_penetracion_1["Provincia"].astype("category")

df_internet_penetracion_1["Accesos por cada 100 hogares"] = df_internet_penetracion_1["Accesos por cada 100 hogares"].str.replace(",", ".").astype("float64")

df_internet_penetracion_1.to_csv(r"Transformados\acceso_xhogares_xprovincia.csv")
df_internet_penetracion_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           840 non-null    category
#  1   Trimestre                     840 non-null    category
#  2   Provincia                     840 non-null    category
#  3   Accesos por cada 100 hogares  840 non-null    float64
# dtypes: category(3), float64(1)
# memory usage: 10.4 KB
